# %% [markdown]
# <a href="https://colab.research.google.com/github/Shiyam-S-27/AI-lab-experiments/blob/main/Exp_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Write a python program to sort the sentence in
# alphabetical order

# %%
sentence = input("Enter a sentence: ")
words = sorted(sentence.split())
sorted_sentence = " ".join(words)
print("Sorted sentence:", sorted_sentence)
# Out:
# Enter a sentence: hello everyone
# Sorted sentence: everyone hello
