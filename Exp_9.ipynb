# %% [markdown]
# <a href="https://colab.research.google.com/github/Shiyam-S-27/AI-lab-experiments/blob/main/Exp_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Write a Python Program to Remove punctuations
# from the given String

# %%
import string
input_string = input("Enter a string: ")
no_punctuations = input_string.translate(str.maketrans("", "", string.punctuation))
print("String with no punctuations:", no_punctuations)
# Out:
# Enter a string: hello everyone, good morning
# String with no punctuations: hello everyone good morning
